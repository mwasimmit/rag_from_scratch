# %%
#!pip install -U langchain-ollama

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model_name="llama-3.1-70b-versatile",
    temperature=0,
    groq_api_key="key here"
)

# %%
#!pip install langchain_community tiktoken langchainhub chromadb langchain

# %%
# Documents
question = "What kinds of pets do I like?"
document = "My favorite pet is a cat."

# %%
import tiktoken

def num_tokens_from_string(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

num_tokens_from_string(question, "cl100k_base")
# Out:
# 7

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
langchain_api_key = os.environ.get("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")

os.environ['OPENAI_API_KEY']=os.getenv("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")

# %%
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model=llm
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[39], line 3
#       1 from langchain_ollama import OllamaEmbeddings
# ----> 3 embeddings = OllamaEmbeddings(
#       4     model=llm
#       5 )
#
# File D:\gen_Learning\rag\rag_from_scratch\first_rag\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
# ...

# %%
single_vector = embeddings.embed_query(question)
legth(single_vector)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File D:\gen_Learning\rag\rag_from_scratch\first_rag\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#      89         raise mapped_exc(message) from exc
#      92 HTTPCORE_EXC_MAP = {
#      93     httpcore.TimeoutException: TimeoutException,
#      94     httpcore.ConnectTimeout: ConnectTimeout,
#      95     httpcore.ReadTimeout: ReadTimeout,
#      96     httpcore.WriteTimeout: WriteTimeout,
#      97     httpcore.PoolTimeout: PoolTimeout,
#      98     httpcore.NetworkError: NetworkError,
#      99     httpcore.ConnectError: ConnectError,
#     100     httpcore.ReadError: ReadError,
# --> 101     httpcore.WriteError: WriteError,
#     102     httpcore.ProxyError: ProxyError,
#     103     httpcore.UnsupportedProtocol: UnsupportedProtocol,
#     104     httpcore.ProtocolError: ProtocolError,
# ...

# %%
import os

os.environ["LANGCHAIN_TRACING_V2"] = "true"
langchain_api_key = os.environ.get("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")
from langchain_ollama import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="llama3",
)
question = "What is the meaning of life?"
single_vector = embeddings.embed_query(question)
print(len(single_vector))
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File D:\gen_Learning\rag\rag_from_scratch\first_rag\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#      89         raise mapped_exc(message) from exc
#      92 HTTPCORE_EXC_MAP = {
#      93     httpcore.TimeoutException: TimeoutException,
#      94     httpcore.ConnectTimeout: ConnectTimeout,
#      95     httpcore.ReadTimeout: ReadTimeout,
#      96     httpcore.WriteTimeout: WriteTimeout,
#      97     httpcore.PoolTimeout: PoolTimeout,
#      98     httpcore.NetworkError: NetworkError,
#      99     httpcore.ConnectError: ConnectError,
#     100     httpcore.ReadError: ReadError,
# --> 101     httpcore.WriteError: WriteError,
#     102     httpcore.ProxyError: ProxyError,
#     103     httpcore.UnsupportedProtocol: UnsupportedProtocol,
#     104     httpcore.ProtocolError: ProtocolError,
# ...

# %%
from langchain_openai import OpenAIEmbeddings
embd = OpenAIEmbeddings()
query_result = embd.embed_query(question)
document_result = embd.embed_query(document)
len(query_result)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 from langchain_openai import OpenAIEmbeddings
# ----> 2 embd = OpenAIEmbeddings()
#       3 query_result = embd.embed_query(question)
#       4 document_result = embd.embed_query(document)
#
#     [... skipping hidden 1 frame]
#
# File D:\gen_Learning\rag\rag_from_scratch\first_rag\Lib\site-packages\langchain_openai\embeddings\base.py:338, in OpenAIEmbeddings.validate_environment(self)
#     336         self.http_client = httpx.Client(proxy=self.openai_proxy)
#     337     sync_specific = {"http_client": self.http_client}
# --> 338     self.client = openai.OpenAI(**client_params, **sync_specific).embeddings  # type: ignore[arg-type]
#     339 if not self.async_client:
#     340     if self.openai_proxy and not self.http_async_client:
#
# ...
